# %% [markdown]
# # Ensemble Methods: Stacking Multiple Models
#
# This notebook demonstrates how to combine multiple machine learning models using stacking to improve prediction performance for bike count prediction.
#
# ## Overview
# - **Stacking**: Combines predictions from multiple base models (LightGBM, XGBoost, Random Forest)
# - **Meta-model**: Uses a Random Forest as the final estimator to combine base predictions
# - **Preprocessing**: Uses TableVectorizer for consistent feature processing across all models

# %%
from sklearn.ensemble import RandomForestRegressor, StackingRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from skrub import TableVectorizer
import utils
import best_params

# %%
X, y, X_test = utils.get_and_process_data()
# Out:
# /Users/gregzguegue/Python_Data_Challenge/utils.py:221: FutureWarning: The behavior of Series.argmax/argmin with skipna=False and NAs, or with all-NAs is deprecated. In a future version this will raise ValueError.
#   (non_nan_values - value).abs().argmin()
# /Users/gregzguegue/Python_Data_Challenge/utils.py:221: FutureWarning: The behavior of Series.argmax/argmin with skipna=False and NAs, or with all-NAs is deprecated. In a future version this will raise ValueError.
#   (non_nan_values - value).abs().argmin()
# /Users/gregzguegue/Python_Data_Challenge/utils.py:387: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:387: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:392: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:397: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:397: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:402: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:407: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:407: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:412: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:412: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][

# %%
# Initialisation des modèles
lgbm = LGBMRegressor(**best_params.parameters_LGBM)
rf = RandomForestRegressor(**best_params.parameters_RandomForest)
xgb = XGBRegressor(**best_params.parameters_XGBoost)

# Création du préprocesseur avec TableVectorizer
preprocessor = ColumnTransformer(
    transformers=[
        (
            "vectorizer",
            TableVectorizer(),
            X.columns,
        )  # Appliquer TableVectorizer à toutes les colonnes
    ]
)

# Création des pipelines pour les modèles
lgbm_pipeline = Pipeline(steps=[("preprocessor", preprocessor), ("model", lgbm)])
rf_pipeline = Pipeline(steps=[("preprocessor", preprocessor), ("model", rf)])
xgb_pipeline = Pipeline(steps=[("preprocessor", preprocessor), ("model", xgb)])

# Création du StackingRegressor
stacking_regressor = StackingRegressor(
    estimators=[("lgbm", lgbm_pipeline), ("rf", rf_pipeline), ("xgb", xgb_pipeline)],
    final_estimator=RandomForestRegressor(random_state=42),  # Meta-modèle
)

# %%
# Entraîner le modèle de stacking
stacking_regressor.fit(X, y)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.158418 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3948
# [LightGBM] [Info] Number of data points in the train set: 496827, number of used features: 118
# [LightGBM] [Info] Start training from score 3.075693
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.122506 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4057
# [LightGBM] [Info] Number of data points in the train set: 397461, number of used features: 112
# [LightGBM] [Info] Start training from score 3.088043
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.128271 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3893
# [LightGBM] [Info] Number of data points in the train set: 397461, number of used features: 114
# [LightGBM] [Info] Start training from score 3.082651
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.140293 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3855
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 112
# [LightGBM] [Info] Start training from score 3.126055
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.188654 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3921
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 113
# [LightGBM] [Info] Start training from score 3.087597
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.111227 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3796
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 113
# [LightGBM] [Info] Start training from score 2.994118
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# StackingRegressor(estimators=[('lgbm',
#                                Pipeline(steps=[('preprocessor',
#                                                 ColumnTransformer(transformers=[('vectorizer',
#                                                                                  TableVectorizer(),
#                                                                                  Index(['counter_id', 'site_id', 'date', 'counter_installation_date',
#        'counter_technical_id', 'latitude', 'longitude',
#        'Pressure_Tendency_(hPa/3h)', 'Pressure_Tendency_Code',
#        'Wind_Direction_(°)', 'Wind_Speed_(m/s)', 'Air_Temper...
#                                                              learning_rate=0.11981406065938047,
#                                                              max_bin=None,
#                                                              max_cat_threshold=None,
#                                                              max_cat_to_onehot=None,
#                                                              max_delta_step=None,
#                                                              max_depth=6,
#                                                              max_leaves=None,
#                                                              min_child_weight=None,
#                                                              missing=nan,
#                                                              monotone_constraints=None,
#                                                              multi_strategy=None,
#                                                              n_estimators=190,
#                                                              n_jobs=None,
#                                                              num_parallel_tree=None,
#                                                              random_state=42, ...))]))],
#                   final_estimator=RandomForestRegressor(random_state=42))

# %%
submission = utils.test_fit_and_submission(X_test, stacking_regressor)
