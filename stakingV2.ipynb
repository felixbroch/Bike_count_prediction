# %%
from sklearn.ensemble import StackingRegressor
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from skrub import TableVectorizer
from sklearn.linear_model import RidgeCV
import utils
import best_params

# %%
X, y, X_test = utils.get_and_process_data()
# Out:
# /Users/gregzguegue/Python_Data_Challenge/utils.py:439: FutureWarning: The behavior of Series.argmax/argmin with skipna=False and NAs, or with all-NAs is deprecated. In a future version this will raise ValueError.
#   (non_nan_values - value).abs().argmin()
# /Users/gregzguegue/Python_Data_Challenge/utils.py:439: FutureWarning: The behavior of Series.argmax/argmin with skipna=False and NAs, or with all-NAs is deprecated. In a future version this will raise ValueError.
#   (non_nan_values - value).abs().argmin()
# /Users/gregzguegue/Python_Data_Challenge/utils.py:596: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:601: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:601: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:606: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:606: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:611: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:611: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:616: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:616: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:621: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["log_bike_count"][
# /Users/gregzguegue/Python_Data_Challenge/utils.py:621: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_bike_count"][

# %%
# Initialisation des modèles
lgbm = LGBMRegressor(**best_params.parameters_LGBM)
xgb = XGBRegressor(**best_params.parameters_XGBoost)

# Création du préprocesseur avec TableVectorizer
preprocessor = ColumnTransformer(
    transformers=[
        (
            "vectorizer",
            TableVectorizer(),
            X.columns,
        )  # Appliquer TableVectorizer à toutes les colonnes
    ]
)

# Création des pipelines pour les modèles
lgbm_pipeline = Pipeline(steps=[("preprocessor", preprocessor), ("model", lgbm)])
xgb_pipeline = Pipeline(steps=[("preprocessor", preprocessor), ("model", xgb)])

# Création du StackingRegressor
stacking_regressor = StackingRegressor(
    estimators=[("lgbm", lgbm_pipeline), ("xgb", xgb_pipeline)],
    final_estimator=XGBRegressor(booster="gblinear"),
)  # Meta-modèle

# %%
# Entraîner le modèle de stacking
stacking_regressor.fit(X, y)
# Out:
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.222813 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3948
# [LightGBM] [Info] Number of data points in the train set: 496827, number of used features: 118
# [LightGBM] [Info] Start training from score 3.075693
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.134324 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4058
# [LightGBM] [Info] Number of data points in the train set: 397461, number of used features: 112
# [LightGBM] [Info] Start training from score 3.088043
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.143611 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3893
# [LightGBM] [Info] Number of data points in the train set: 397461, number of used features: 114
# [LightGBM] [Info] Start training from score 3.082651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.134903 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3855
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 112
# [LightGBM] [Info] Start training from score 3.126055
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.142094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3921
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 113
# [LightGBM] [Info] Start training from score 3.087597
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.134164 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3798
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 113
# [LightGBM] [Info] Start training from score 2.994118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# StackingRegressor(estimators=[('lgbm',
#                                Pipeline(steps=[('preprocessor',
#                                                 ColumnTransformer(transformers=[('vectorizer',
#                                                                                  TableVectorizer(),
#                                                                                  Index(['counter_id', 'site_id', 'date', 'counter_installation_date',
#        'counter_technical_id', 'latitude', 'longitude',
#        'Pressure_Tendency_(hPa/3h)', 'Pressure_Tendency_Code',
#        'Wind_Direction_(°)', 'Wind_Speed_(m/s)', 'Air_Temper...
#                                                grow_policy=None,
#                                                importance_type=None,
#                                                interaction_constraints=None,
#                                                learning_rate=None, max_bin=None,
#                                                max_cat_threshold=None,
#                                                max_cat_to_onehot=None,
#                                                max_delta_step=None,
#                                                max_depth=None, max_leaves=None,
#                                                min_child_weight=None,
#                                                missing=nan,
#                                                monotone_constraints=None,
#                                                multi_strategy=None,
#                                                n_estimators=None, n_jobs=None,
#                                                num_parallel_tree=None,
#                                                random_state=None, ...))

# %%
submission = utils.test_fit_and_submission(X_test, stacking_regressor)
# Out:
# [LightGBM] [Warning] Unknown parameter: tree_method

# %%
# Création du StackingRegressor
stacking_regressor_ridge = StackingRegressor(
    estimators=[("lgbm", lgbm_pipeline), ("xgb", xgb_pipeline)],
    final_estimator=RidgeCV()
)  # Meta-modèle

# %%
# Entraîner le modèle de stacking
stacking_regressor_ridge.fit(X, y)
# Out:
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.164062 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3948
# [LightGBM] [Info] Number of data points in the train set: 496827, number of used features: 118
# [LightGBM] [Info] Start training from score 3.075693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.133159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4058
# [LightGBM] [Info] Number of data points in the train set: 397461, number of used features: 112
# [LightGBM] [Info] Start training from score 3.088043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.195416 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3893
# [LightGBM] [Info] Number of data points in the train set: 397461, number of used features: 114
# [LightGBM] [Info] Start training from score 3.082651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.161472 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3855
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 112
# [LightGBM] [Info] Start training from score 3.126055
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.148466 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3921
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 113
# [LightGBM] [Info] Start training from score 3.087597
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.158799 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3798
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 113
# [LightGBM] [Info] Start training from score 2.994118
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# StackingRegressor(estimators=[('lgbm',
#                                Pipeline(steps=[('preprocessor',
#                                                 ColumnTransformer(transformers=[('vectorizer',
#                                                                                  TableVectorizer(),
#                                                                                  Index(['counter_id', 'site_id', 'date', 'counter_installation_date',
#        'counter_technical_id', 'latitude', 'longitude',
#        'Pressure_Tendency_(hPa/3h)', 'Pressure_Tendency_Code',
#        'Wind_Direction_(°)', 'Wind_Speed_(m/s)', 'Air_Temper...
#                                                              importance_type=None,
#                                                              interaction_constraints=None,
#                                                              learning_rate=None,
#                                                              max_bin=None,
#                                                              max_cat_threshold=None,
#                                                              max_cat_to_onehot=None,
#                                                              max_delta_step=None,
#                                                              max_depth=None,
#                                                              max_leaves=None,
#                                                              min_child_weight=None,
#                                                              missing=nan,
#                                                              monotone_constraints=None,
#                                                              multi_strategy=None,
#                                                              n_estimators=None,
#                                                              n_jobs=None,
#                                                              num_parallel_tree=None,
#                                                              random_state=None, ...))]))],
#                   final_estimator=RidgeCV())

# %%
# Création du StackingRegressor
double_stacking_regressor = StackingRegressor(
    estimators=[("stacking_XGboost", stacking_regressor), ("stacking_Ridge", stacking_regressor_ridge)],
    final_estimator=RidgeCV()
)  # Meta-modèle

# %%
# Entraîner le modèle de stacking
double_stacking_regressor.fit(X, y)
# Out:
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.249635 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3948
# [LightGBM] [Info] Number of data points in the train set: 496827, number of used features: 118
# [LightGBM] [Info] Start training from score 3.075693
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.162893 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4058
# [LightGBM] [Info] Number of data points in the train set: 397461, number of used features: 112
# [LightGBM] [Info] Start training from score 3.088043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.153599 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3893
# [LightGBM] [Info] Number of data points in the train set: 397461, number of used features: 114
# [LightGBM] [Info] Start training from score 3.082651
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.188466 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3855
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 112
# [LightGBM] [Info] Start training from score 3.126055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.142035 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3921
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 113
# [LightGBM] [Info] Start training from score 3.087597
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.170745 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3798
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 113
# [LightGBM] [Info] Start training from score 2.994118
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.179844 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3948
# [LightGBM] [Info] Number of data points in the train set: 496827, number of used features: 118
# [LightGBM] [Info] Start training from score 3.075693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.136625 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4058
# [LightGBM] [Info] Number of data points in the train set: 397461, number of used features: 112
# [LightGBM] [Info] Start training from score 3.088043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.170799 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3893
# [LightGBM] [Info] Number of data points in the train set: 397461, number of used features: 114
# [LightGBM] [Info] Start training from score 3.082651
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.163793 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3855
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 112
# [LightGBM] [Info] Start training from score 3.126055
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.148584 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3921
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 113
# [LightGBM] [Info] Start training from score 3.087597
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Warning] Unknown parameter: tree_method
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.145790 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3798
# [LightGBM] [Info] Number of data points in the train set: 397462, number of used features: 113
# [LightGBM] [Info] Start training from score 2.994118
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# [LightGBM] [Warning] Unknown parameter: tree_method
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:242: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/ensemble/_stacking.py:162, in _BaseStacking._method_name(name, estimator, method)
#     161 try:
# --> 162     method_name = _check_response_method(estimator, method).__name__
#     163 except AttributeError as e:
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/utils/validation.py:2145, in _check_response_method(estimator, response_method)
#    2144 if prediction_method is None:
# -> 2145     raise AttributeError(
#    2146         f"{estimator.__class__.__name__} has none of the following attributes: "
#    2147         f"{', '.join(list_methods)}."
#    2148     )
#    2150 return prediction_method
#
# AttributeError: StackingRegressor has none of the following attributes: predict.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Entraîner le modèle de stacking
# ----> 2 double_stacking_regressor.fit(X, y)
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/ensemble/_stacking.py:971, in StackingRegressor.fit(self, X, y, sample_weight)
#     969 _raise_for_unsupported_routing(self, "fit", sample_weight=sample_weight)
#     970 y = column_or_1d(y, warn=True)
# --> 971 return super().fit(X, y, sample_weight)
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/ensemble/_stacking.py:224, in _BaseStacking.fit(self, X, y, sample_weight)
#     219             self.estimators_.append(estimator)
#     220 else:
#     221     # Fit the base estimators on the whole training data. Those
#     222     # base estimators will be used in transform, predict, and
#     223     # predict_proba. They are exposed publicly.
# --> 224     self.estimators_ = Parallel(n_jobs=self.n_jobs)(
#     225         delayed(_fit_single_estimator)(clone(est), X, y, fit_params)
#     226         for est in all_estimators
#     227         if est != "drop"
#     228     )
#     230 self.named_estimators_ = Bunch()
#     231 est_fitted_idx = 0
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/utils/parallel.py:74, in Parallel.__call__(self, iterable)
#      69 config = get_config()
#      70 iterable_with_config = (
#      71     (_with_config(delayed_func, config), args, kwargs)
#      72     for delayed_func, args, kwargs in iterable
#      73 )
# ---> 74 return super().__call__(iterable_with_config)
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/joblib/parallel.py:1918, in Parallel.__call__(self, iterable)
#    1916     output = self._get_sequential_output(iterable)
#    1917     next(output)
# -> 1918     return output if self.return_generator else list(output)
#    1920 # Let's create an ID that uniquely identifies the current call. If the
#    1921 # call is interrupted early and that the same instance is immediately
#    1922 # re-used, this id will be used to prevent workers that were
#    1923 # concurrently finalizing a task from the previous call to run the
#    1924 # callback.
#    1925 with self._lock:
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/joblib/parallel.py:1847, in Parallel._get_sequential_output(self, iterable)
#    1845 self.n_dispatched_batches += 1
#    1846 self.n_dispatched_tasks += 1
# -> 1847 res = func(*args, **kwargs)
#    1848 self.n_completed_tasks += 1
#    1849 self.print_progress()
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/utils/parallel.py:136, in _FuncWrapper.__call__(self, *args, **kwargs)
#     134     config = {}
#     135 with config_context(**config):
# --> 136     return self.function(*args, **kwargs)
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/ensemble/_base.py:40, in _fit_single_estimator(estimator, X, y, fit_params, message_clsname, message)
#      38 else:
#      39     with _print_elapsed_time(message_clsname, message):
# ---> 40         estimator.fit(X, y, **fit_params)
#      41 return estimator
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/ensemble/_stacking.py:971, in StackingRegressor.fit(self, X, y, sample_weight)
#     969 _raise_for_unsupported_routing(self, "fit", sample_weight=sample_weight)
#     970 y = column_or_1d(y, warn=True)
# --> 971 return super().fit(X, y, sample_weight)
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/ensemble/_stacking.py:243, in _BaseStacking.fit(self, X, y, sample_weight)
#     239     else:
#     240         self.named_estimators_[name_est] = "drop"
#     242 self.stack_method_ = [
# --> 243     self._method_name(name, est, meth)
#     244     for name, est, meth in zip(names, all_estimators, stack_method)
#     245 ]
#     247 if self.cv == "prefit":
#     248     # Generate predictions from prefit models
#     249     predictions = [
#     250         getattr(estimator, predict_method)(X)
#     251         for estimator, predict_method in zip(all_estimators, self.stack_method_)
#     252         if estimator != "drop"
#     253     ]
#
# File /opt/anaconda3/envs/py312-myenv/lib/python3.12/site-packages/sklearn/ensemble/_stacking.py:164, in _BaseStacking._method_name(name, estimator, method)
#     162     method_name = _check_response_method(estimator, method).__name__
#     163 except AttributeError as e:
# --> 164     raise ValueError(
#     165         f"Underlying estimator {name} does not implement the method {method}."
#     166     ) from e
#     168 return method_name
#
# ValueError: Underlying estimator stacking_Ridge does not implement the method predict.
